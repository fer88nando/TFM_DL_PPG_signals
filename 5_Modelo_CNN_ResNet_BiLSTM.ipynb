# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Preprocesamiento de los datos

# %%
########################################################################################    BBDD CHINA
X_train = pd.read_pickle("./Datasets/China/X_train_China_Augmented.pkl")
X_val = pd.read_pickle("./Datasets/China/X_val_China.pkl")
X_test = pd.read_pickle("./Datasets/China/X_test_China.pkl")

y_train = pd.read_pickle("./Datasets/China/y_train_China_Augmented.pkl")
y_val = pd.read_pickle("./Datasets/China/y_val_China.pkl")
y_test = pd.read_pickle("./Datasets/China/y_test_China.pkl")

fs = 1000

# %%
########################################################################################    BBDD COLOMBIA
X_train = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/X_train_Augmented_PCA.pkl"))
X_val = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/X_val.pkl"))
X_test = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/X_test.pkl"))

y_train = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/y_train_Augmented_PCA.pkl"))
y_val = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/y_val.pkl"))
y_test = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/y_test.pkl"))

fs = 100

# %%
############################################################################################# Suavizado y normalización solo para BBDD China
def moving_average(signal, window_size=5):  #Windows Size = 50 para BBDD China y 5 para BBDD Colombia
    return np.convolve(signal, np.ones(window_size)/window_size, mode='valid')
    
# Convertir cada fila del DataFrame en un arreglo de NumPy y aplicar el suavizado
X_train = np.array([moving_average(ppg_signal.values) for _, ppg_signal in X_train.iterrows()]) #Comentar si X_train_China_Augmented ya que está filtrado en el proceso de Data Augmentation
X_val = np.array([moving_average(ppg_signal.values) for _, ppg_signal in X_val.iterrows()])
X_test = np.array([moving_average(ppg_signal.values) for _, ppg_signal in X_test.iterrows()])

# Normalización Min-Max
def normalize_min_max(signals):
    # Calcular mínimos y máximos por fila
    min_vals = np.min(signals, axis=1, keepdims=True)
    max_vals = np.max(signals, axis=1, keepdims=True)
    # Normalizar cada fila
    return (signals - min_vals) / (max_vals - min_vals)

X_train = normalize_min_max(X_train)
X_val = normalize_min_max(X_val)
X_test = normalize_min_max(X_test)

# %%
import numpy as np
import pandas as pd
import pywt

def wavelet_df(
    df: pd.DataFrame, 
    wavelet='db4', 
    level=6
):
    """
    Aplica wavelet a cada fila de un DataFrame.
    
    Parámetros
    ----------
    df       : DataFrame de forma (n_señales, n_muestras). 
               Cada fila es una señal 1D.
    wavelet  : str. Nombre de la wavelet (ej. 'db4', 'sym4', etc.).
    level    : int. Nivel de descomposición wavelet.
               
    Retorna
    -------
    cA_array   : np.array de forma (n_señales, n_muestras). 
                 Aproximación reconstruida para cada señal.
    cD6_array  : np.array de forma (n_señales, n_muestras). 
                 Aproximación reconstruida para cada señal.
    """
    
    n_señales = df.shape[0]
    n_muestras = df.shape[1]
    
    # Para guardar resultados
    cA_array = np.zeros((n_señales, n_muestras))
    cD_array = np.zeros((n_señales, n_muestras))
    
    for i in range(n_señales):
        # 1) Extraer la señal (fila i) como array 1D
        signal = df.iloc[i].values  # (n_muestras,)
        
        # 2) Descomposición wavelet -> cA
        coeffs = pywt.wavedec(signal, wavelet=wavelet, level=level)
        cA = coeffs[0]  # Aproximación en el nivel 'level'
        cD_level = coeffs[1]
        
        # 3) Reconstruir cA al tamaño original
        cA_rec = pywt.upcoef(
            part='a',
            coeffs=cA,
            wavelet=wavelet,
            level=level,
            take=n_muestras
        )

        dA6_rec = pywt.upcoef(
            part='d',
            coeffs=cD_level,
            wavelet=wavelet,
            level=level,
            take=n_muestras
        )        
        # 6) Guardar resultados
        cA_array[i, :] = cA_rec
        cD_array[i, :] = dA6_rec 
    
    return cA_array, cD_array

import matplotlib.pyplot as plt

def plot_wavelet_emd(signal, cA_rec, cD_rec, level=5):
    """
    Grafica la señal original, la aproximación cA{level} y las IMFs obtenidas por EMD.
    """
    num_plots = 3  # señal + cA + cada IMF
    
    fig, axes = plt.subplots(num_plots, 1, figsize=(15, 2 * num_plots), sharex=True)
    #fig.suptitle(f"Wavelet (nivel={level}) + EMD en cA")

    # 1) Señal original
    axes[0].plot(signal, 'b')
    axes[0].set_title("Señal original")
    
    # 2) Aproximación cA{level}
    axes[1].plot(cA_rec, 'g')
    axes[1].set_title(f"Aproximación Wavelet cA{level} (reconstruida)")
    
    axes[2].plot(cD_rec, 'r')
    axes[2].set_title(f"Detalle Wavelet cD{level} (reconstruida)")

    plt.tight_layout()
    plt.show()

# %%
#level = 6  # Nivel de detalle para BBDD China
level = 3 # Nivel de detalle para BBDD Colombia
cA_array_train, cD_array_train = wavelet_df(
    pd.DataFrame(X_train), 
    wavelet='db4', 
    level=level
)

cA_array_val, cD_array_val = wavelet_df(
    pd.DataFrame(X_val), 
    wavelet='db4', 
    level=level
)

cA_array_test, cD_array_test = wavelet_df(
    pd.DataFrame(X_test), 
    wavelet='db4', 
    level=level
)

print("cA_array_train.shape:", cA_array_train.shape) 
print("cD_array_train.shape:", cD_array_train.shape)
# Out:
# cA_array_train.shape: (2170, 196)
# cD_array_train.shape: (2170, 196)

# %%
######################################### Ejecutar solo con BBDD China
from scipy.signal import decimate
#Hacemos Downsampling por explosión del gradiente en mi ordenador

def downsampling(array, q=2):
    array_downsampled = np.array([decimate(signal, q=q, axis=0) for signal in array])
    return array_downsampled

q=6
X_train = downsampling(X_train, q)
X_val = downsampling(X_val, q) 
X_test = downsampling(X_test, q)

cD_array_train = downsampling(cD_array_train, q)
cD_array_val = downsampling(cD_array_val, q)
cD_array_test = downsampling(cD_array_test, q)

# %%
X_train = np.expand_dims(X_train, axis=-1)
X_val = np.expand_dims(X_val, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

y_train = y_train.astype(int).values.ravel()
y_val = y_val.astype(int).values.ravel()
y_test = y_test.astype(int).values.ravel()

# %%
index = 0
plot_wavelet_emd(X_train[index,:], cA_array_train[index], cD_array_train[index], level=level)

# %% [markdown]
# # CNN-ResNet-BiLSTM

# %%
from keras.callbacks import TensorBoard

import os

# Crear carpeta para guardar los logs de TensorBoard
log_dir = os.path.join("logs", "modelo_cnn_resnet_bilstm")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# Verificar la carpeta creada
print(f"Logs de TensorBoard se guardarán en: {log_dir}")
# Out:
# Logs de TensorBoard se guardarán en: logs\modelo_cnn_resnet_bilstm

# %%
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, Activation, Dropout, Add,
    AveragePooling1D, Bidirectional, LSTM, Dense, Concatenate, Flatten
)
from tensorflow.keras.models import Model

def create_resnet_bilstm_with_wavelet_fixed(input_shape_ppg, wavelet_length):
    """
    Modelo CNN-ResNet-BiLSTM con entrada para wavelets.

    Args:
    - input_shape_ppg: Tuple con la forma de las señales PPG (n_timesteps, n_features).
    - wavelet_length: Longitud de los coeficientes wavelet.

    Returns:
    - model: Modelo compilado listo para entrenar.
    """
    # 🔹 Entrada de PPG
    ppg_input = Input(shape=input_shape_ppg, name='PPG_Input')

    # Primera capa convolucional
    x = Conv1D(64, kernel_size=15, padding="same")(ppg_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Bloques ResNet
    def residual_block(x, filters):
        shortcut = Conv1D(filters, kernel_size=1, padding='same')(x)

        x = Conv1D(filters, kernel_size=7, padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Dropout(0.2)(x)

        x = Conv1D(filters, kernel_size=7, padding='same')(x)
        x = BatchNormalization()(x)

        x = Add()([x, shortcut])
        x = Activation('relu')(x)

        # Cambiamos a AvgPooling
        x = AveragePooling1D(pool_size=2)(x)
        return x

    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = residual_block(x, 128)
    x = residual_block(x, 128)

    # BiLSTM
    x = Bidirectional(LSTM(128, return_sequences=True, dropout=0.3))(x)
    x = Bidirectional(LSTM(64, return_sequences=False, dropout=0.3))(x)

    # 🔹 Aplanar la salida PPG
    x = Flatten()(x)

    # 🔹 Entrada de Wavelet
    wavelet_input = Input(shape=(wavelet_length,), name="Wavelet_Input")
    y = Dense(128, activation='relu', name="Wavelet_Dense_1")(wavelet_input)
    y = Dropout(0.3, name="Wavelet_Dropout_1")(y)
    y = Dense(64, activation='relu', name="Wavelet_Dense_2")(y)
    y = Dropout(0.3, name="Wavelet_Dropout_2")(y)

    # 🔹 Combinación de ambas entradas
    combined = Concatenate(name="PPG_Wavelet_Concatenation")([x, y])

    # 🔹 Capas densas finales
    z = Dense(64, activation=None, kernel_regularizer=tf.keras.regularizers.l2(0.01), name="Dense_1")(combined)
    z = BatchNormalization()(z)
    z = Activation('relu')(z)
    z = Dropout(0.4)(z)

    z = Dense(32, activation=None, kernel_regularizer=tf.keras.regularizers.l2(0.01), name="Dense_2")(z)
    z = BatchNormalization()(z)
    z = Activation('relu')(z)
    z = Dropout(0.3)(z)

    # Capa de salida
    output = Dense(1, activation='sigmoid', name="Output")(z)

    # Construcción del modelo
    model = Model(inputs=[ppg_input, wavelet_input], outputs=output)
    return model

# %%
from tensorflow.keras.optimizers import AdamW, Adam
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.regularizers import l2

def focal_loss(gamma=2., alpha=0.25):
    def loss(y_true, y_pred):
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        pt = tf.exp(-bce)
        focal_loss = alpha * (1 - pt) ** gamma * bce
        return focal_loss
    return loss

input_shape_ppg = (X_train.shape[1], X_train.shape[2]) 
wavelet_length = cD_array_train.shape[1]

model = create_resnet_bilstm_with_wavelet_fixed(input_shape_ppg, wavelet_length)

optimizer = AdamW(learning_rate=1e-4)
#optimizer = Adam(learning_rate=1e-4, clipnorm=1.0)  

# 🔹 Compilar modelo con focal loss para desbalanceo
model.compile(optimizer=optimizer, loss=focal_loss(), metrics=['accuracy', AUC()])

# 🔹 Calcular pesos de clases para entrenamiento balanceado
classes = np.array([0, 1])
class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weights = {0: class_weights[0], 1: class_weights[1]}

# 🔹 Callbacks para optimización
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
checkpoint = ModelCheckpoint("./Modelos/modelo_cnn_resnet_bilstm/best_model.keras", monitor='val_loss', save_best_only=True)

model.save('./Modelos/modelo_cnn_resnet_bilstm/modelo_cnn_resnet_bilstm.keras')
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ PPG_Input (InputLayer)        │ (None, 196, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 196, 64)           │           1,024 │ PPG_Input[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 196, 64)           │             256 │ conv1d[0][0]               │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation (Activation)       │ (None, 196, 64)           │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 196, 64)           │          28,736 │ activation[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 196, 64)           │             256 │ conv1d_2[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_1 (Activation)     │ (None, 196, 64)           │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 196, 64)           │               0 │ activation_1[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 196, 64)           │          28,736 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 196, 64)           │             256 │ conv1d_3[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 196, 64)           │           4,160 │ activation[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 196, 64)           │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ conv1d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_2 (Activation)     │ (None, 196, 64)           │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling1d             │ (None, 98, 64)            │               0 │ activation_2[0][0]         │
# │ (AveragePooling1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_5 (Conv1D)             │ (None, 98, 64)            │          28,736 │ average_pooling1d[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 98, 64)            │             256 │ conv1d_5[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_3 (Activation)     │ (None, 98, 64)            │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 98, 64)            │               0 │ activation_3[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_6 (Conv1D)             │ (None, 98, 64)            │          28,736 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 98, 64)            │             256 │ conv1d_6[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 98, 64)            │           4,160 │ average_pooling1d[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 98, 64)            │               0 │ batch_normalization_4[0][… │
# │                               │                           │                 │ conv1d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_4 (Activation)     │ (None, 98, 64)            │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling1d_1           │ (None, 49, 64)            │               0 │ activation_4[0][0]         │
# │ (AveragePooling1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_8 (Conv1D)             │ (None, 49, 128)           │          57,472 │ average_pooling1d_1[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 49, 128)           │             512 │ conv1d_8[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_5 (Activation)     │ (None, 49, 128)           │               0 │ batch_normalization_5[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 49, 128)           │               0 │ activation_5[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_9 (Conv1D)             │ (None, 49, 128)           │         114,816 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 49, 128)           │             512 │ conv1d_9[0][0]             │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_7 (Conv1D)             │ (None, 49, 128)           │           8,320 │ average_pooling1d_1[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 49, 128)           │               0 │ batch_normalization_6[0][… │
# │                               │                           │                 │ conv1d_7[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_6 (Activation)     │ (None, 49, 128)           │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling1d_2           │ (None, 24, 128)           │               0 │ activation_6[0][0]         │
# │ (AveragePooling1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_11 (Conv1D)            │ (None, 24, 128)           │         114,816 │ average_pooling1d_2[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 24, 128)           │             512 │ conv1d_11[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_7 (Activation)     │ (None, 24, 128)           │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_3 (Dropout)           │ (None, 24, 128)           │               0 │ activation_7[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_12 (Conv1D)            │ (None, 24, 128)           │         114,816 │ dropout_3[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 24, 128)           │             512 │ conv1d_12[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_10 (Conv1D)            │ (None, 24, 128)           │          16,512 │ average_pooling1d_2[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 24, 128)           │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ conv1d_10[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_8 (Activation)     │ (None, 24, 128)           │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Input (InputLayer)    │ (None, 196)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling1d_3           │ (None, 12, 128)           │               0 │ activation_8[0][0]         │
# │ (AveragePooling1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Dense_1 (Dense)       │ (None, 128)               │          25,216 │ Wavelet_Input[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional (Bidirectional) │ (None, 12, 256)           │         263,168 │ average_pooling1d_3[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Dropout_1 (Dropout)   │ (None, 128)               │               0 │ Wavelet_Dense_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional_1               │ (None, 128)               │         164,352 │ bidirectional[0][0]        │
# │ (Bidirectional)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Dense_2 (Dense)       │ (None, 64)                │           8,256 │ Wavelet_Dropout_1[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 128)               │               0 │ bidirectional_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Dropout_2 (Dropout)   │ (None, 64)                │               0 │ Wavelet_Dense_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ PPG_Wavelet_Concatenation     │ (None, 192)               │               0 │ flatten[0][0],             │
# │ (Concatenate)                 │                           │                 │ Wavelet_Dropout_2[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Dense_1 (Dense)               │ (None, 64)                │          12,352 │ PPG_Wavelet_Concatenation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 64)                │             256 │ Dense_1[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_9 (Activation)     │ (None, 64)                │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 64)                │               0 │ activation_9[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Dense_2 (Dense)               │ (None, 32)                │           2,080 │ dropout_4[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 32)                │             128 │ Dense_2[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_10 (Activation)    │ (None, 32)                │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 32)                │               0 │ activation_10[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Output (Dense)                │ (None, 1)                 │              33 │ dropout_5[0][0]            │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,030,209 (3.93 MB)
#  Trainable params: 1,028,353 (3.92 MB)
#  Non-trainable params: 1,856 (7.25 KB)

# %%
# 🔹 Entrenamiento con optimización mejorada
history = model.fit([X_train, cD_array_train], y_train, 
                    epochs=50, batch_size=32,
                    validation_data=([X_val, cD_array_val], y_val),
                    class_weight=class_weights, 
                    callbacks=[tensorboard_callback, reduce_lr, checkpoint])
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 93ms/step - accuracy: 0.5152 - auc: 0.5181 - loss: 1.4160 - val_accuracy: 0.6250 - val_auc: 0.5077 - val_loss: 1.3019 - learning_rate: 1.0000e-04
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.5137 - auc: 0.5108 - loss: 1.3030 - val_accuracy: 0.6250 - val_auc: 0.5105 - val_loss: 1.1984 - learning_rate: 1.0000e-04
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.5428 - auc: 0.5586 - loss: 1.1949 - val_accuracy: 0.3750 - val_auc: 0.5531 - val_loss: 1.1044 - learning_rate: 1.0000e-04
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.5537 - auc: 0.5914 - loss: 1.0980 - val_accuracy: 0.3750 - val_auc: 0.5824 - val_loss: 1.0177 - learning_rate: 1.0000e-04
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.5340 - auc: 0.5554 - loss: 1.0144 - val_accuracy: 0.3750 - val_auc: 0.5153 - val_loss: 0.9402 - learning_rate: 1.0000e-04
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.5730 - auc: 0.6151 - loss: 0.9280 - val_accuracy: 0.3750 - val_auc: 0.5400 - val_loss: 0.8708 - learning_rate: 1.0000e-04
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.5671 - auc: 0.6135 - loss: 0.8549 - val_accuracy: 0.3750 - val_auc: 0.5589 - val_loss: 0.7986 - learning_rate: 1.0000e-04
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.6098 - auc: 0.6572 - loss: 0.7822 - val_accuracy: 0.3910 - val_auc: 0.4377 - val_loss: 0.7296 - learning_rate: 1.0000e-04
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6317 - auc: 0.6601 - loss: 0.7192 - val_accuracy: 0.4936 - val_auc: 0.5289 - val_loss: 0.6701 - learning_rate: 1.0000e-04
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6124 - auc: 0.6681 - loss: 0.6606 - val_accuracy: 0.5000 - val_auc: 0.4417 - val_loss: 0.6342 - learning_rate: 1.0000e-04
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.6132 - auc: 0.6770 - loss: 0.6063 - val_accuracy: 0.6058 - val_auc: 0.5923 - val_loss: 0.5704 - learning_rate: 1.0000e-04
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.6034 - auc: 0.6709 - loss: 0.5554 - val_accuracy: 0.5609 - val_auc: 0.4508 - val_loss: 0.5901 - learning_rate: 1.0000e-04
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.6261 - auc: 0.6987 - loss: 0.5101 - val_accuracy: 0.5865 - val_auc: 0.4223 - val_loss: 0.6175 - learning_rate: 1.0000e-04
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6220 - auc: 0.6791 - loss: 0.4756 - val_accuracy: 0.6282 - val_auc: 0.6489 - val_loss: 0.4930 - learning_rate: 5.0000e-05
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6244 - auc: 0.6954 - loss: 0.4556 - val_accuracy: 0.5545 - val_auc: 0.5418 - val_loss: 0.4826 - learning_rate: 5.0000e-05
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.6375 - auc: 0.7046 - loss: 0.4362 - val_accuracy: 0.5609 - val_auc: 0.5173 - val_loss: 0.4916 - learning_rate: 5.0000e-05
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.6449 - auc: 0.7052 - loss: 0.4185 - val_accuracy: 0.5801 - val_auc: 0.6158 - val_loss: 0.4239 - learning_rate: 5.0000e-05
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.6441 - auc: 0.7140 - loss: 0.3981 - val_accuracy: 0.5994 - val_auc: 0.5367 - val_loss: 0.5446 - learning_rate: 5.0000e-05
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6452 - auc: 0.7202 - loss: 0.3794 - val_accuracy: 0.5801 - val_auc: 0.5997 - val_loss: 0.4023 - learning_rate: 5.0000e-05
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.6485 - auc: 0.7298 - loss: 0.3639 - val_accuracy: 0.6442 - val_auc: 0.6586 - val_loss: 0.4063 - learning_rate: 5.0000e-05
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6593 - auc: 0.7320 - loss: 0.3494 - val_accuracy: 0.7276 - val_auc: 0.7758 - val_loss: 0.3395 - learning_rate: 5.0000e-05
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.6815 - auc: 0.7513 - loss: 0.3332 - val_accuracy: 0.5641 - val_auc: 0.6165 - val_loss: 0.4137 - learning_rate: 5.0000e-05
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.6827 - auc: 0.7715 - loss: 0.3161 - val_accuracy: 0.5577 - val_auc: 0.6092 - val_loss: 0.3230 - learning_rate: 5.0000e-05
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.6913 - auc: 0.7647 - loss: 0.3024 - val_accuracy: 0.5577 - val_auc: 0.6282 - val_loss: 0.3235 - learning_rate: 5.0000e-05
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.6962 - auc: 0.7623 - loss: 0.2894 - val_accuracy: 0.6058 - val_auc: 0.6996 - val_loss: 0.2982 - learning_rate: 5.0000e-05
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7002 - auc: 0.7847 - loss: 0.2748 - val_accuracy: 0.5705 - val_auc: 0.5748 - val_loss: 0.4143 - learning_rate: 5.0000e-05
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.6783 - auc: 0.7726 - loss: 0.2646 - val_accuracy: 0.5481 - val_auc: 0.4781 - val_loss: 0.4315 - learning_rate: 5.0000e-05
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.6852 - auc: 0.7920 - loss: 0.2517 - val_accuracy: 0.5545 - val_auc: 0.5650 - val_loss: 0.3943 - learning_rate: 2.5000e-05
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7112 - auc: 0.7976 - loss: 0.2462 - val_accuracy: 0.5064 - val_auc: 0.5446 - val_loss: 0.3735 - learning_rate: 2.5000e-05
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7201 - auc: 0.7998 - loss: 0.2410 - val_accuracy: 0.5288 - val_auc: 0.5576 - val_loss: 0.3590 - learning_rate: 1.2500e-05
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7006 - auc: 0.7958 - loss: 0.2394 - val_accuracy: 0.5449 - val_auc: 0.4948 - val_loss: 0.4061 - learning_rate: 1.2500e-05
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7217 - auc: 0.8079 - loss: 0.2363 - val_accuracy: 0.5224 - val_auc: 0.5158 - val_loss: 0.3816 - learning_rate: 6.2500e-06
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.7227 - auc: 0.8084 - loss: 0.2345 - val_accuracy: 0.5256 - val_auc: 0.5318 - val_loss: 0.3724 - learning_rate: 6.2500e-06
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.7170 - auc: 0.8063 - loss: 0.2330 - val_accuracy: 0.5224 - val_auc: 0.5374 - val_loss: 0.3595 - learning_rate: 3.1250e-06
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7159 - auc: 0.8065 - loss: 0.2323 - val_accuracy: 0.5224 - val_auc: 0.5393 - val_loss: 0.3519 - learning_rate: 3.1250e-06
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7113 - auc: 0.8023 - loss: 0.2316 - val_accuracy: 0.5224 - val_auc: 0.5396 - val_loss: 0.3536 - learning_rate: 1.5625e-06
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7048 - auc: 0.7955 - loss: 0.2319 - val_accuracy: 0.5224 - val_auc: 0.5370 - val_loss: 0.3536 - learning_rate: 1.5625e-06
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7244 - auc: 0.8053 - loss: 0.2304 - val_accuracy: 0.5224 - val_auc: 0.5346 - val_loss: 0.3592 - learning_rate: 1.0000e-06
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7205 - auc: 0.8194 - loss: 0.2290 - val_accuracy: 0.5192 - val_auc: 0.5329 - val_loss: 0.3618 - learning_rate: 1.0000e-06
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7136 - auc: 0.8145 - loss: 0.2293 - val_accuracy: 0.5192 - val_auc: 0.5310 - val_loss: 0.3607 - learning_rate: 1.0000e-06
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7140 - auc: 0.7950 - loss: 0.2306 - val_accuracy: 0.5224 - val_auc: 0.5337 - val_loss: 0.3611 - learning_rate: 1.0000e-06
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.6861 - auc: 0.7895 - loss: 0.2307 - val_accuracy: 0.5224 - val_auc: 0.5362 - val_loss: 0.3587 - learning_rate: 1.0000e-06
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.6943 - auc: 0.7839 - loss: 0.2309 - val_accuracy: 0.5224 - val_auc: 0.5374 - val_loss: 0.3622 - learning_rate: 1.0000e-06
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7144 - auc: 0.8054 - loss: 0.2295 - val_accuracy: 0.5224 - val_auc: 0.5419 - val_loss: 0.3560 - learning_rate: 1.0000e-06
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7176 - auc: 0.8041 - loss: 0.2300 - val_accuracy: 0.5128 - val_auc: 0.5389 - val_loss: 0.3585 - learning_rate: 1.0000e-06
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7215 - auc: 0.8223 - loss: 0.2273 - val_accuracy: 0.5128 - val_auc: 0.5383 - val_loss: 0.3596 - learning_rate: 1.0000e-06
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7133 - auc: 0.8091 - loss: 0.2280 - val_accuracy: 0.5128 - val_auc: 0.5377 - val_loss: 0.3569 - learning_rate: 1.0000e-06
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7212 - auc: 0.8207 - loss: 0.2275 - val_accuracy: 0.5128 - val_auc: 0.5336 - val_loss: 0.3619 - learning_rate: 1.0000e-06
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7101 - auc: 0.8059 - loss: 0.2289 - val_accuracy: 0.5160 - val_auc: 0.5368 - val_loss: 0.3616 - learning_rate: 1.0000e-06
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.7051 - auc: 0.7939 - loss: 0.2283 - val_accuracy: 0.5192 - val_auc: 0.5361 - val_loss: 0.3604 - learning_rate: 1.0000e-06

# %% [markdown]
# # RESULTADOS ENTRENAMIENTO

# %%
test_loss, test_accuracy, test_auc = model.evaluate([X_val, cD_array_val], y_val)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test AUC: {test_auc:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6046 - auc: 0.3191 - loss: 0.3281
# Test Loss: 0.3604
# Test Accuracy: 0.5192
# Test AUC: 0.5361

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_probs_val = model.predict([X_val, cD_array_val])  # Devuelve las probabilidades para cada clase


# Calcular la curva ROC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_probs_val)
roc_auc = auc(fpr, tpr)
# Calcular la diferencia entre TPR y FPR
optimal_idx = np.argmax(tpr - fpr)  # Índice del umbral óptimo
optimal_threshold = thresholds[optimal_idx]  # Umbral óptimo


threshold = optimal_threshold  # Umbral de decisión
y_pred = (y_pred_probs_val > threshold).astype(int)  # 1 para "Normal", 0 para "Anormal"
#y_pred = (y_pred_probs_test > 0.5).astype(int)  # Convierte a 0 o 1

# Calcular la matriz de confusión
cm = confusion_matrix(y_val, y_pred)



# Graficar la matriz de confusión
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Patologia", "Normal"], yticklabels=["Patologia", "Normal"])
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de Confusión")


# Graficar la curva ROC
plt.subplot(1,2,2)
plt.plot(fpr, tpr, color='blue', label=f'AUC = {roc_auc:.3f}')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')  # Línea de referencia
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend()
plt.show()

print(f"\nUmbral óptimo: {optimal_threshold}\n" )

# Reporte de clasificación
print("Reporte de Clasificación:\n", classification_report(y_val, y_pred, target_names=['Patologia', 'Normal']))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step
# Umbral óptimo: 0.03834645450115204
#
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#    Patologia       0.83      0.34      0.49       195
#       Normal       0.45      0.88      0.59       117
#
#     accuracy                           0.54       312
#    macro avg       0.64      0.61      0.54       312
# weighted avg       0.68      0.54      0.53       312

# %%
plt.figure(figsize=(20, 5))

# Gráfica de la pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Pérdida entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Evolución de la Pérdida")

# Gráfica de la precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Precisión entrenamiento')
plt.plot(history.history['val_accuracy'], label='Precisión validación')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.title("Evolución de la Precisión")

plt.show()

# %% [markdown]
# # RESULTADOS FUERA DE MUESTRA

# %%
test_loss, test_accuracy, test_auc = model.evaluate([X_test, cD_array_test], y_test)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test AUC: {test_auc:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6824 - auc: 0.6208 - loss: 0.3312
# Test Loss: 0.3430
# Test Accuracy: 0.6359
# Test AUC: 0.6921

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_probs_test = model.predict([X_test, cD_array_test])  # Devuelve las probabilidades para cada clase


# Calcular la curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs_test)
roc_auc = auc(fpr, tpr)
# Calcular la diferencia entre TPR y FPR
optimal_idx = np.argmax(tpr - fpr)  # Índice del umbral óptimo
optimal_threshold = thresholds[optimal_idx]  # Umbral óptimo


threshold = optimal_threshold  # Umbral de decisión
y_pred = (y_pred_probs_test > threshold).astype(int)  # 1 para "Normal", 0 para "Anormal"
#y_pred = (y_pred_probs_test > 0.5).astype(int)  # Convierte a 0 o 1

# Calcular la matriz de confusión
cm = confusion_matrix(y_test, y_pred)



# Graficar la matriz de confusión
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Patologia", "Normal"], yticklabels=["Patologia", "Normal"])
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de Confusión")


# Graficar la curva ROC
plt.subplot(1,2,2)
plt.plot(fpr, tpr, color='blue', label=f'AUC = {roc_auc:.3f}')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')  # Línea de referencia
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend()
plt.show()

print(f"\nUmbral óptimo: {optimal_threshold}\n" )

# Reporte de clasificación
print("Reporte de Clasificación:\n", classification_report(y_test, y_pred, target_names=['Patologia', 'Normal']))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Umbral óptimo: 0.4720973074436188
#
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#    Patologia       0.59      0.93      0.73       195
#       Normal       0.85      0.36      0.51       195
#
#     accuracy                           0.65       390
#    macro avg       0.72      0.65      0.62       390
# weighted avg       0.72      0.65      0.62       390

# %%
import matplotlib.pyplot as plt
import numpy as np

# Separar las probabilidades según la clase
proba_normal = y_pred_probs_test[y_test == 1]  # Probabilidades de la clase "Normal"
proba_patologia = y_pred_probs_test[y_test == 0]  # Probabilidades de la clase "Patologia"

# Crear histogramas
plt.figure(figsize=(10, 5))
plt.hist(proba_patologia, bins=20, alpha=0.6, label="Patología", color='red', edgecolor='black')
plt.hist(proba_normal, bins=20, alpha=0.6, label="Normal", color='blue', edgecolor='black')

# Personalización
plt.axvline(x=optimal_threshold, color='green', linestyle='dashed', label=f"Umbral óptimo: {optimal_threshold}")
plt.xlabel("Probabilidad de ser Normal")
plt.ylabel("Frecuencia")
plt.title("Distribución de Probabilidades de Clase")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.hist(np.mean(X_train[:,:,0], axis=1), bins=30, alpha=0.5, label="Entrenamiento PPG", color='blue', density=True)
plt.hist(np.mean(X_test[:,:,0], axis=1), bins=30, alpha=0.5, label="Fuera de muestra PPG", color='red', density=True)
plt.xlabel("Media de Amplitud")
plt.ylabel("Densidad")
plt.legend()
plt.title("Comparación de Distribución - PPG")
plt.show()

plt.figure(figsize=(12, 5))
plt.hist(np.mean(cD_array_train, axis=1), bins=30, alpha=0.5, label="Entrenamiento Wavelet", color='blue', density=True)
plt.hist(np.mean(cD_array_test, axis=1), bins=30, alpha=0.5, label="Fuera de muestra Wavelet", color='red', density=True)
plt.xlabel("Media de Amplitud")
plt.ylabel("Densidad")
plt.legend()
plt.title("Comparación de Distribución - Wavelet")
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train[:,:,0])
X_test_pca = pca.transform(X_test[:,:,0])

plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], label="Entrenamiento", alpha=0.5)
plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], label="Fuera de Muestra", alpha=0.5)
plt.legend()
plt.title("Comparación de Distribución con PCA")
plt.show()

# %% [markdown]
# # Guardar el modelo

# %%
from tensorflow.keras.utils import plot_model
import visualkeras
from PIL import ImageFont

font = ImageFont.truetype("arial.ttf", 32)

plot_model(model, to_file='./Modelos/modelo_cnn_resnet_bilstm/model_plot.png', show_shapes=True, show_layer_names=True)

visualkeras.layered_view(
    model, 
    font=font,
    legend=True, 
    spacing=50,  # Más espacio entre capas
    scale_xy=2,  # Escala horizontal/vertical
    scale_z=1    # Reducir la profundidad 3D para que sea más claro
).save('./Modelos/modelo_cnn_resnet_bilstm/keras_3D.png')

visualkeras.layered_view(
    model, 
    font=font,
    legend=True, 
    spacing=40, 
    draw_volume=False  # Desactiva la vista en 3D
).save('./Modelos/modelo_cnn_resnet_bilstm/keras_2D.png')

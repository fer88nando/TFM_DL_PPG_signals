# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Preprocesamiento de los datos

# %%
########################################################################################    BBDD CHINA
X_train = pd.read_pickle("./Datasets/China/X_train_China_Augmented.pkl")
X_val = pd.read_pickle("./Datasets/China/X_val_China.pkl")
X_test = pd.read_pickle("./Datasets/China/X_test_China.pkl")

y_train = pd.read_pickle("./Datasets/China/y_train_China_Augmented.pkl")
y_val = pd.read_pickle("./Datasets/China/y_val_China.pkl")
y_test = pd.read_pickle("./Datasets/China/y_test_China.pkl")

fs = 1000

# %%
########################################################################################    BBDD COLOMBIA
X_train = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/X_train_Augmented_GAN.pkl"))
X_val = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/X_val.pkl"))
X_test = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/X_test.pkl"))

y_train = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/y_train_Augmented_GAN.pkl"))
y_val = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/y_val.pkl"))
y_test = pd.DataFrame(pd.read_pickle("./Datasets/Colombia/y_test.pkl"))

fs = 100

# %%
############################################################################################# Suavizado y normalización solo para BBDD China
def moving_average(signal, window_size=5):  #Windows Size = 50 para BBDD China y 5 para BBDD Colombia
    return np.convolve(signal, np.ones(window_size)/window_size, mode='valid')
    
# Convertir cada fila del DataFrame en un arreglo de NumPy y aplicar el suavizado
X_train = np.array([moving_average(ppg_signal.values) for _, ppg_signal in X_train.iterrows()]) #Comentar si X_train_China_Augmented ya que está filtrado en el proceso de Data Augmentation
X_val = np.array([moving_average(ppg_signal.values) for _, ppg_signal in X_val.iterrows()])
X_test = np.array([moving_average(ppg_signal.values) for _, ppg_signal in X_test.iterrows()])

# Normalización Min-Max
def normalize_min_max(signals):
    # Calcular mínimos y máximos por fila
    min_vals = np.min(signals, axis=1, keepdims=True)
    max_vals = np.max(signals, axis=1, keepdims=True)
    # Normalizar cada fila
    return (signals - min_vals) / (max_vals - min_vals)

X_train = normalize_min_max(X_train)
X_val = normalize_min_max(X_val)
X_test = normalize_min_max(X_test)

# %%
import numpy as np
import pandas as pd
import pywt

def wavelet_df(
    df: pd.DataFrame, 
    wavelet='db4', 
    level=6
):
    """
    Aplica wavelet a cada fila de un DataFrame.
    
    Parámetros
    ----------
    df       : DataFrame de forma (n_señales, n_muestras). 
               Cada fila es una señal 1D.
    wavelet  : str. Nombre de la wavelet (ej. 'db4', 'sym4', etc.).
    level    : int. Nivel de descomposición wavelet.
               
    Retorna
    -------
    cA_array   : np.array de forma (n_señales, n_muestras). 
                 Aproximación reconstruida para cada señal.
    cD6_array  : np.array de forma (n_señales, n_muestras). 
                 Aproximación reconstruida para cada señal.
    """
    
    n_señales = df.shape[0]
    n_muestras = df.shape[1]
    
    # Para guardar resultados
    cA_array = np.zeros((n_señales, n_muestras))
    cD_array = np.zeros((n_señales, n_muestras))
    
    for i in range(n_señales):
        # 1) Extraer la señal (fila i) como array 1D
        signal = df.iloc[i].values  # (n_muestras,)
        
        # 2) Descomposición wavelet -> cA
        coeffs = pywt.wavedec(signal, wavelet=wavelet, level=level)
        cA = coeffs[0]  # Aproximación en el nivel 'level'
        cD_level = coeffs[1]
        
        # 3) Reconstruir cA al tamaño original
        cA_rec = pywt.upcoef(
            part='a',
            coeffs=cA,
            wavelet=wavelet,
            level=level,
            take=n_muestras
        )

        dA6_rec = pywt.upcoef(
            part='d',
            coeffs=cD_level,
            wavelet=wavelet,
            level=level,
            take=n_muestras
        )        
        # 6) Guardar resultados
        cA_array[i, :] = cA_rec
        cD_array[i, :] = dA6_rec 
    
    return cA_array, cD_array

import matplotlib.pyplot as plt

def plot_wavelet_emd(signal, cA_rec, cD_rec, level=5):
    """
    Grafica la señal original, la aproximación cA{level} y las IMFs obtenidas por EMD.
    """
    num_plots = 3  # señal + cA + cada IMF
    
    fig, axes = plt.subplots(num_plots, 1, figsize=(15, 2 * num_plots), sharex=True)
    #fig.suptitle(f"Wavelet (nivel={level}) + EMD en cA")

    # 1) Señal original
    axes[0].plot(signal, 'b')
    axes[0].set_title("Señal original")
    
    # 2) Aproximación cA{level}
    axes[1].plot(cA_rec, 'g')
    axes[1].set_title(f"Aproximación Wavelet cA{level} (reconstruida)")
    
    axes[2].plot(cD_rec, 'r')
    axes[2].set_title(f"Detalle Wavelet cD{level} (reconstruida)")

    plt.tight_layout()
    plt.show()

# %%
#level = 6  # Nivel de detalle para BBDD China
level = 3 # Nivel de detalle para BBDD Colombia
cA_array_train, cD_array_train = wavelet_df(
    pd.DataFrame(X_train), 
    wavelet='db4', 
    level=level
)

cA_array_val, cD_array_val = wavelet_df(
    pd.DataFrame(X_val), 
    wavelet='db4', 
    level=level
)

cA_array_test, cD_array_test = wavelet_df(
    pd.DataFrame(X_test), 
    wavelet='db4', 
    level=level
)

print("cA_array_train.shape:", cA_array_train.shape) 
print("cD_array_train.shape:", cD_array_train.shape)
# Out:
# cA_array_train.shape: (2170, 196)
# cD_array_train.shape: (2170, 196)

# %%
######################################### Ejecutar solo con BBDD China
from scipy.signal import decimate
#Hacemos Downsampling por explosión del gradiente en mi ordenador

def downsampling(array, q=2):
    array_downsampled = np.array([decimate(signal, q=q, axis=0) for signal in array])
    return array_downsampled

q=6
X_train = downsampling(X_train, q)
X_val = downsampling(X_val, q) 
X_test = downsampling(X_test, q)

cD_array_train = downsampling(cD_array_train, q)
cD_array_val = downsampling(cD_array_val, q)
cD_array_test = downsampling(cD_array_test, q)

# %%
X_train = np.expand_dims(X_train, axis=-1)
X_val = np.expand_dims(X_val, axis=-1)
X_test = np.expand_dims(X_test, axis=-1)

y_train = y_train.astype(int).values.ravel()
y_val = y_val.astype(int).values.ravel()
y_test = y_test.astype(int).values.ravel()

# %%
index = 0
plot_wavelet_emd(X_train[index,:], cA_array_train[index], cD_array_train[index], level=level)

# %% [markdown]
# # CNN-ResNet-BiLSTM

# %%
from keras.callbacks import TensorBoard

import os

# Crear carpeta para guardar los logs de TensorBoard
log_dir = os.path.join("logs", "modelo_cnn_resnet_bilstm")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# Verificar la carpeta creada
print(f"Logs de TensorBoard se guardarán en: {log_dir}")
# Out:
# Logs de TensorBoard se guardarán en: logs\modelo_cnn_resnet_bilstm

# %%
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, Activation, Dropout, Add,
    AveragePooling1D, Bidirectional, LSTM, Dense, Concatenate, Flatten
)
from tensorflow.keras.models import Model

def create_resnet_bilstm_with_wavelet_fixed(input_shape_ppg, wavelet_length):
    """
    Modelo CNN-ResNet-BiLSTM con entrada para wavelets.

    Args:
    - input_shape_ppg: Tuple con la forma de las señales PPG (n_timesteps, n_features).
    - wavelet_length: Longitud de los coeficientes wavelet.

    Returns:
    - model: Modelo compilado listo para entrenar.
    """
    # 🔹 Entrada de PPG
    ppg_input = Input(shape=input_shape_ppg, name='PPG_Input')

    # Primera capa convolucional
    x = Conv1D(64, kernel_size=15, padding="same")(ppg_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Bloques ResNet
    def residual_block(x, filters):
        shortcut = Conv1D(filters, kernel_size=1, padding='same')(x)

        x = Conv1D(filters, kernel_size=7, padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Dropout(0.2)(x)

        x = Conv1D(filters, kernel_size=7, padding='same')(x)
        x = BatchNormalization()(x)

        x = Add()([x, shortcut])
        x = Activation('relu')(x)

        # Cambiamos a AvgPooling
        x = AveragePooling1D(pool_size=2)(x)
        return x

    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = residual_block(x, 128)
    x = residual_block(x, 128)

    # BiLSTM
    x = Bidirectional(LSTM(128, return_sequences=True, dropout=0.3))(x)
    x = Bidirectional(LSTM(64, return_sequences=False, dropout=0.3))(x)

    # 🔹 Aplanar la salida PPG
    x = Flatten()(x)

    # 🔹 Entrada de Wavelet
    wavelet_input = Input(shape=(wavelet_length,), name="Wavelet_Input")
    y = Dense(128, activation='relu', name="Wavelet_Dense_1")(wavelet_input)
    y = Dropout(0.3, name="Wavelet_Dropout_1")(y)
    y = Dense(64, activation='relu', name="Wavelet_Dense_2")(y)
    y = Dropout(0.3, name="Wavelet_Dropout_2")(y)

    # 🔹 Combinación de ambas entradas
    combined = Concatenate(name="PPG_Wavelet_Concatenation")([x, y])

    # 🔹 Capas densas finales
    z = Dense(64, activation=None, kernel_regularizer=tf.keras.regularizers.l2(0.01), name="Dense_1")(combined)
    z = BatchNormalization()(z)
    z = Activation('relu')(z)
    z = Dropout(0.4)(z)

    z = Dense(32, activation=None, kernel_regularizer=tf.keras.regularizers.l2(0.01), name="Dense_2")(z)
    z = BatchNormalization()(z)
    z = Activation('relu')(z)
    z = Dropout(0.3)(z)

    # Capa de salida
    output = Dense(1, activation='sigmoid', name="Output")(z)

    # Construcción del modelo
    model = Model(inputs=[ppg_input, wavelet_input], outputs=output)
    return model

# %%
from tensorflow.keras.optimizers import AdamW, Adam
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.regularizers import l2

def focal_loss(gamma=2., alpha=0.25):
    def loss(y_true, y_pred):
        bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        pt = tf.exp(-bce)
        focal_loss = alpha * (1 - pt) ** gamma * bce
        return focal_loss
    return loss

input_shape_ppg = (X_train.shape[1], X_train.shape[2]) 
wavelet_length = cD_array_train.shape[1]

model = create_resnet_bilstm_with_wavelet_fixed(input_shape_ppg, wavelet_length)

optimizer = AdamW(learning_rate=1e-4)
#optimizer = Adam(learning_rate=1e-4, clipnorm=1.0)  

# 🔹 Compilar modelo con focal loss para desbalanceo
model.compile(optimizer=optimizer, loss=focal_loss(), metrics=['accuracy', AUC()])

# 🔹 Calcular pesos de clases para entrenamiento balanceado
classes = np.array([0, 1])
class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
class_weights = {0: class_weights[0], 1: class_weights[1]}

# 🔹 Callbacks para optimización
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
checkpoint = ModelCheckpoint("./Modelos/modelo_cnn_resnet_bilstm/best_model.keras", monitor='val_loss', save_best_only=True)

model.save('./Modelos/modelo_cnn_resnet_bilstm/modelo_cnn_resnet_bilstm.keras')
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ PPG_Input (InputLayer)        │ (None, 196, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_52 (Conv1D)            │ (None, 196, 64)           │           1,024 │ PPG_Input[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_44        │ (None, 196, 64)           │             256 │ conv1d_52[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_44 (Activation)    │ (None, 196, 64)           │               0 │ batch_normalization_44[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_54 (Conv1D)            │ (None, 196, 64)           │          28,736 │ activation_44[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_45        │ (None, 196, 64)           │             256 │ conv1d_54[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_45 (Activation)    │ (None, 196, 64)           │               0 │ batch_normalization_45[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_24 (Dropout)          │ (None, 196, 64)           │               0 │ activation_45[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_55 (Conv1D)            │ (None, 196, 64)           │          28,736 │ dropout_24[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_46        │ (None, 196, 64)           │             256 │ conv1d_55[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_53 (Conv1D)            │ (None, 196, 64)           │           4,160 │ activation_44[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_16 (Add)                  │ (None, 196, 64)           │               0 │ batch_normalization_46[0]… │
# │                               │                           │                 │ conv1d_53[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_46 (Activation)    │ (None, 196, 64)           │               0 │ add_16[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling1d_16          │ (None, 98, 64)            │               0 │ activation_46[0][0]        │
# │ (AveragePooling1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_57 (Conv1D)            │ (None, 98, 64)            │          28,736 │ average_pooling1d_16[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_47        │ (None, 98, 64)            │             256 │ conv1d_57[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_47 (Activation)    │ (None, 98, 64)            │               0 │ batch_normalization_47[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_25 (Dropout)          │ (None, 98, 64)            │               0 │ activation_47[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_58 (Conv1D)            │ (None, 98, 64)            │          28,736 │ dropout_25[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_48        │ (None, 98, 64)            │             256 │ conv1d_58[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_56 (Conv1D)            │ (None, 98, 64)            │           4,160 │ average_pooling1d_16[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_17 (Add)                  │ (None, 98, 64)            │               0 │ batch_normalization_48[0]… │
# │                               │                           │                 │ conv1d_56[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_48 (Activation)    │ (None, 98, 64)            │               0 │ add_17[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling1d_17          │ (None, 49, 64)            │               0 │ activation_48[0][0]        │
# │ (AveragePooling1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_60 (Conv1D)            │ (None, 49, 128)           │          57,472 │ average_pooling1d_17[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_49        │ (None, 49, 128)           │             512 │ conv1d_60[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_49 (Activation)    │ (None, 49, 128)           │               0 │ batch_normalization_49[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_26 (Dropout)          │ (None, 49, 128)           │               0 │ activation_49[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_61 (Conv1D)            │ (None, 49, 128)           │         114,816 │ dropout_26[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_50        │ (None, 49, 128)           │             512 │ conv1d_61[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_59 (Conv1D)            │ (None, 49, 128)           │           8,320 │ average_pooling1d_17[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_18 (Add)                  │ (None, 49, 128)           │               0 │ batch_normalization_50[0]… │
# │                               │                           │                 │ conv1d_59[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_50 (Activation)    │ (None, 49, 128)           │               0 │ add_18[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling1d_18          │ (None, 24, 128)           │               0 │ activation_50[0][0]        │
# │ (AveragePooling1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_63 (Conv1D)            │ (None, 24, 128)           │         114,816 │ average_pooling1d_18[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_51        │ (None, 24, 128)           │             512 │ conv1d_63[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_51 (Activation)    │ (None, 24, 128)           │               0 │ batch_normalization_51[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_27 (Dropout)          │ (None, 24, 128)           │               0 │ activation_51[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_64 (Conv1D)            │ (None, 24, 128)           │         114,816 │ dropout_27[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_52        │ (None, 24, 128)           │             512 │ conv1d_64[0][0]            │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_62 (Conv1D)            │ (None, 24, 128)           │          16,512 │ average_pooling1d_18[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_19 (Add)                  │ (None, 24, 128)           │               0 │ batch_normalization_52[0]… │
# │                               │                           │                 │ conv1d_62[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_52 (Activation)    │ (None, 24, 128)           │               0 │ add_19[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Input (InputLayer)    │ (None, 196)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ average_pooling1d_19          │ (None, 12, 128)           │               0 │ activation_52[0][0]        │
# │ (AveragePooling1D)            │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Dense_1 (Dense)       │ (None, 128)               │          25,216 │ Wavelet_Input[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional_8               │ (None, 12, 256)           │         263,168 │ average_pooling1d_19[0][0] │
# │ (Bidirectional)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Dropout_1 (Dropout)   │ (None, 128)               │               0 │ Wavelet_Dense_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional_9               │ (None, 128)               │         164,352 │ bidirectional_8[0][0]      │
# │ (Bidirectional)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Dense_2 (Dense)       │ (None, 64)                │           8,256 │ Wavelet_Dropout_1[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_4 (Flatten)           │ (None, 128)               │               0 │ bidirectional_9[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Wavelet_Dropout_2 (Dropout)   │ (None, 64)                │               0 │ Wavelet_Dense_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ PPG_Wavelet_Concatenation     │ (None, 192)               │               0 │ flatten_4[0][0],           │
# │ (Concatenate)                 │                           │                 │ Wavelet_Dropout_2[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Dense_1 (Dense)               │ (None, 64)                │          12,352 │ PPG_Wavelet_Concatenation… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_53        │ (None, 64)                │             256 │ Dense_1[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_53 (Activation)    │ (None, 64)                │               0 │ batch_normalization_53[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_28 (Dropout)          │ (None, 64)                │               0 │ activation_53[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Dense_2 (Dense)               │ (None, 32)                │           2,080 │ dropout_28[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_54        │ (None, 32)                │             128 │ Dense_2[0][0]              │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ activation_54 (Activation)    │ (None, 32)                │               0 │ batch_normalization_54[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_29 (Dropout)          │ (None, 32)                │               0 │ activation_54[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Output (Dense)                │ (None, 1)                 │              33 │ dropout_29[0][0]           │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,030,209 (3.93 MB)
#  Trainable params: 1,028,353 (3.92 MB)
#  Non-trainable params: 1,856 (7.25 KB)

# %%
# 🔹 Entrenamiento con optimización mejorada
history = model.fit([X_train, cD_array_train], y_train, 
                    epochs=50, batch_size=32,
                    validation_data=([X_val, cD_array_val], y_val),
                    class_weight=class_weights, 
                    callbacks=[tensorboard_callback, reduce_lr, checkpoint])
# Out:
# Epoch 1/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 20s 90ms/step - accuracy: 0.5076 - auc_4: 0.5145 - loss: 1.4462 - val_accuracy: 0.6250 - val_auc_4: 0.4949 - val_loss: 1.3265 - learning_rate: 1.0000e-04
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.5356 - auc_4: 0.5692 - loss: 1.3273 - val_accuracy: 0.6250 - val_auc_4: 0.4102 - val_loss: 1.2261 - learning_rate: 1.0000e-04
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.5268 - auc_4: 0.5702 - loss: 1.2318 - val_accuracy: 0.3750 - val_auc_4: 0.4972 - val_loss: 1.1398 - learning_rate: 1.0000e-04
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.5426 - auc_4: 0.5903 - loss: 1.1348 - val_accuracy: 0.3750 - val_auc_4: 0.5359 - val_loss: 1.1425 - learning_rate: 1.0000e-04
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.5733 - auc_4: 0.6014 - loss: 1.0523 - val_accuracy: 0.3750 - val_auc_4: 0.4842 - val_loss: 1.1388 - learning_rate: 1.0000e-04
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6002 - auc_4: 0.6769 - loss: 0.9642 - val_accuracy: 0.3750 - val_auc_4: 0.5448 - val_loss: 1.0916 - learning_rate: 1.0000e-04
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6265 - auc_4: 0.6879 - loss: 0.8933 - val_accuracy: 0.3750 - val_auc_4: 0.6124 - val_loss: 1.0514 - learning_rate: 1.0000e-04
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6115 - auc_4: 0.6718 - loss: 0.8314 - val_accuracy: 0.3750 - val_auc_4: 0.5667 - val_loss: 0.9929 - learning_rate: 1.0000e-04
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6552 - auc_4: 0.7354 - loss: 0.7599 - val_accuracy: 0.3750 - val_auc_4: 0.5921 - val_loss: 0.8171 - learning_rate: 1.0000e-04
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.6429 - auc_4: 0.7054 - loss: 0.7044 - val_accuracy: 0.5064 - val_auc_4: 0.5236 - val_loss: 0.6852 - learning_rate: 1.0000e-04
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6391 - auc_4: 0.7021 - loss: 0.6539 - val_accuracy: 0.6058 - val_auc_4: 0.6211 - val_loss: 0.6252 - learning_rate: 1.0000e-04
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6590 - auc_4: 0.7554 - loss: 0.5976 - val_accuracy: 0.5865 - val_auc_4: 0.5835 - val_loss: 0.5831 - learning_rate: 1.0000e-04
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6943 - auc_4: 0.7803 - loss: 0.5500 - val_accuracy: 0.6859 - val_auc_4: 0.7021 - val_loss: 0.5250 - learning_rate: 1.0000e-04
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.6699 - auc_4: 0.7527 - loss: 0.5110 - val_accuracy: 0.6987 - val_auc_4: 0.6980 - val_loss: 0.4885 - learning_rate: 1.0000e-04
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6911 - auc_4: 0.7732 - loss: 0.4702 - val_accuracy: 0.7276 - val_auc_4: 0.7502 - val_loss: 0.4462 - learning_rate: 1.0000e-04
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6961 - auc_4: 0.7829 - loss: 0.4338 - val_accuracy: 0.7115 - val_auc_4: 0.6766 - val_loss: 0.4213 - learning_rate: 1.0000e-04
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7250 - auc_4: 0.8209 - loss: 0.3974 - val_accuracy: 0.6442 - val_auc_4: 0.6185 - val_loss: 0.4146 - learning_rate: 1.0000e-04
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7122 - auc_4: 0.8080 - loss: 0.3674 - val_accuracy: 0.6026 - val_auc_4: 0.6321 - val_loss: 0.3962 - learning_rate: 1.0000e-04
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7312 - auc_4: 0.8292 - loss: 0.3378 - val_accuracy: 0.5769 - val_auc_4: 0.6204 - val_loss: 0.3417 - learning_rate: 1.0000e-04
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7056 - auc_4: 0.8212 - loss: 0.3132 - val_accuracy: 0.5929 - val_auc_4: 0.5750 - val_loss: 0.3342 - learning_rate: 1.0000e-04
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7631 - auc_4: 0.8598 - loss: 0.2844 - val_accuracy: 0.6122 - val_auc_4: 0.6793 - val_loss: 0.2882 - learning_rate: 1.0000e-04
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7807 - auc_4: 0.8682 - loss: 0.2622 - val_accuracy: 0.6571 - val_auc_4: 0.6780 - val_loss: 0.2794 - learning_rate: 1.0000e-04
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7698 - auc_4: 0.8746 - loss: 0.2414 - val_accuracy: 0.5224 - val_auc_4: 0.5128 - val_loss: 0.3024 - learning_rate: 1.0000e-04
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.7880 - auc_4: 0.8860 - loss: 0.2215 - val_accuracy: 0.5833 - val_auc_4: 0.4699 - val_loss: 0.3094 - learning_rate: 1.0000e-04
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.8125 - auc_4: 0.9007 - loss: 0.2048 - val_accuracy: 0.5160 - val_auc_4: 0.5583 - val_loss: 0.2595 - learning_rate: 5.0000e-05
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.7952 - auc_4: 0.9019 - loss: 0.1954 - val_accuracy: 0.5224 - val_auc_4: 0.5555 - val_loss: 0.2741 - learning_rate: 5.0000e-05
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8035 - auc_4: 0.9026 - loss: 0.1880 - val_accuracy: 0.5417 - val_auc_4: 0.5864 - val_loss: 0.2561 - learning_rate: 5.0000e-05
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.8061 - auc_4: 0.9157 - loss: 0.1781 - val_accuracy: 0.6442 - val_auc_4: 0.6820 - val_loss: 0.2482 - learning_rate: 5.0000e-05
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.8213 - auc_4: 0.9145 - loss: 0.1712 - val_accuracy: 0.6410 - val_auc_4: 0.6793 - val_loss: 0.2262 - learning_rate: 5.0000e-05
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8366 - auc_4: 0.9302 - loss: 0.1625 - val_accuracy: 0.6218 - val_auc_4: 0.6461 - val_loss: 0.2375 - learning_rate: 5.0000e-05
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8172 - auc_4: 0.9114 - loss: 0.1578 - val_accuracy: 0.6346 - val_auc_4: 0.6709 - val_loss: 0.2590 - learning_rate: 5.0000e-05
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8136 - auc_4: 0.9145 - loss: 0.1515 - val_accuracy: 0.6122 - val_auc_4: 0.6734 - val_loss: 0.2195 - learning_rate: 2.5000e-05
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8503 - auc_4: 0.9357 - loss: 0.1455 - val_accuracy: 0.5865 - val_auc_4: 0.6440 - val_loss: 0.2257 - learning_rate: 2.5000e-05
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8249 - auc_4: 0.9238 - loss: 0.1447 - val_accuracy: 0.5994 - val_auc_4: 0.6371 - val_loss: 0.2261 - learning_rate: 2.5000e-05
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8543 - auc_4: 0.9429 - loss: 0.1388 - val_accuracy: 0.5865 - val_auc_4: 0.6501 - val_loss: 0.2089 - learning_rate: 1.2500e-05
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8450 - auc_4: 0.9301 - loss: 0.1393 - val_accuracy: 0.5545 - val_auc_4: 0.6324 - val_loss: 0.2352 - learning_rate: 1.2500e-05
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8420 - auc_4: 0.9347 - loss: 0.1367 - val_accuracy: 0.5737 - val_auc_4: 0.6263 - val_loss: 0.2225 - learning_rate: 1.2500e-05
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8364 - auc_4: 0.9399 - loss: 0.1340 - val_accuracy: 0.5737 - val_auc_4: 0.6338 - val_loss: 0.2180 - learning_rate: 6.2500e-06
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.8376 - auc_4: 0.9376 - loss: 0.1342 - val_accuracy: 0.5994 - val_auc_4: 0.6639 - val_loss: 0.2064 - learning_rate: 6.2500e-06
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8474 - auc_4: 0.9359 - loss: 0.1349 - val_accuracy: 0.5705 - val_auc_4: 0.6296 - val_loss: 0.2192 - learning_rate: 6.2500e-06
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.8431 - auc_4: 0.9475 - loss: 0.1312 - val_accuracy: 0.5833 - val_auc_4: 0.6448 - val_loss: 0.2170 - learning_rate: 6.2500e-06
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8583 - auc_4: 0.9453 - loss: 0.1308 - val_accuracy: 0.5769 - val_auc_4: 0.6402 - val_loss: 0.2122 - learning_rate: 3.1250e-06
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.8562 - auc_4: 0.9471 - loss: 0.1295 - val_accuracy: 0.5737 - val_auc_4: 0.6337 - val_loss: 0.2198 - learning_rate: 3.1250e-06
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8553 - auc_4: 0.9464 - loss: 0.1294 - val_accuracy: 0.5769 - val_auc_4: 0.6349 - val_loss: 0.2165 - learning_rate: 1.5625e-06
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8573 - auc_4: 0.9526 - loss: 0.1283 - val_accuracy: 0.5737 - val_auc_4: 0.6365 - val_loss: 0.2147 - learning_rate: 1.5625e-06
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8615 - auc_4: 0.9508 - loss: 0.1286 - val_accuracy: 0.5769 - val_auc_4: 0.6377 - val_loss: 0.2145 - learning_rate: 1.0000e-06
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.8615 - auc_4: 0.9485 - loss: 0.1294 - val_accuracy: 0.5705 - val_auc_4: 0.6407 - val_loss: 0.2122 - learning_rate: 1.0000e-06
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8481 - auc_4: 0.9425 - loss: 0.1296 - val_accuracy: 0.5737 - val_auc_4: 0.6425 - val_loss: 0.2121 - learning_rate: 1.0000e-06
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8531 - auc_4: 0.9441 - loss: 0.1289 - val_accuracy: 0.5737 - val_auc_4: 0.6385 - val_loss: 0.2136 - learning_rate: 1.0000e-06
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8532 - auc_4: 0.9500 - loss: 0.1280 - val_accuracy: 0.5705 - val_auc_4: 0.6373 - val_loss: 0.2151 - learning_rate: 1.0000e-06

# %% [markdown]
# # RESULTADOS ENTRENAMIENTO

# %%
test_loss, test_accuracy, test_auc = model.evaluate([X_val, cD_array_val], y_val)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test AUC: {test_auc:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5460 - auc_4: 0.4170 - loss: 0.2317
# Test Loss: 0.2151
# Test Accuracy: 0.5705
# Test AUC: 0.6373

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_probs_val = model.predict([X_val, cD_array_val])  # Devuelve las probabilidades para cada clase


# Calcular la curva ROC
fpr, tpr, thresholds = roc_curve(y_val, y_pred_probs_val)
roc_auc = auc(fpr, tpr)
# Calcular la diferencia entre TPR y FPR
optimal_idx = np.argmax(tpr - fpr)  # Índice del umbral óptimo
optimal_threshold = thresholds[optimal_idx]  # Umbral óptimo


threshold = optimal_threshold  # Umbral de decisión
y_pred = (y_pred_probs_val > threshold).astype(int)  # 1 para "Normal", 0 para "Anormal"
#y_pred = (y_pred_probs_test > 0.5).astype(int)  # Convierte a 0 o 1

# Calcular la matriz de confusión
cm = confusion_matrix(y_val, y_pred)



# Graficar la matriz de confusión
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Patologia", "Normal"], yticklabels=["Patologia", "Normal"])
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de Confusión")


# Graficar la curva ROC
plt.subplot(1,2,2)
plt.plot(fpr, tpr, color='blue', label=f'AUC = {roc_auc:.3f}')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')  # Línea de referencia
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend()
plt.show()

print(f"\nUmbral óptimo: {optimal_threshold}\n" )

# Reporte de clasificación
print("Reporte de Clasificación:\n", classification_report(y_val, y_pred, target_names=['Patologia', 'Normal']))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step
# Umbral óptimo: 0.08735022693872452
#
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#    Patologia       0.94      0.41      0.57       195
#       Normal       0.49      0.96      0.65       117
#
#     accuracy                           0.62       312
#    macro avg       0.72      0.68      0.61       312
# weighted avg       0.77      0.62      0.60       312

# %%
plt.figure(figsize=(20, 5))

# Gráfica de la pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Pérdida entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title("Evolución de la Pérdida")

# Gráfica de la precisión
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Precisión entrenamiento')
plt.plot(history.history['val_accuracy'], label='Precisión validación')
plt.xlabel('Épocas')
plt.ylabel('Precisión')
plt.legend()
plt.title("Evolución de la Precisión")

plt.show()

# %% [markdown]
# # RESULTADOS FUERA DE MUESTRA

# %%
test_loss, test_accuracy, test_auc = model.evaluate([X_test, cD_array_test], y_test)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test AUC: {test_auc:.4f}")
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8521 - auc_4: 0.8166 - loss: 0.1487
# Test Loss: 0.1803
# Test Accuracy: 0.7590
# Test AUC: 0.7930

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_probs_test = model.predict([X_test, cD_array_test])  # Devuelve las probabilidades para cada clase


# Calcular la curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs_test)
roc_auc = auc(fpr, tpr)
# Calcular la diferencia entre TPR y FPR
optimal_idx = np.argmax(tpr - fpr)  # Índice del umbral óptimo
optimal_threshold = thresholds[optimal_idx]  # Umbral óptimo


threshold = optimal_threshold  # Umbral de decisión
y_pred = (y_pred_probs_test > threshold).astype(int)  # 1 para "Normal", 0 para "Anormal"
#y_pred = (y_pred_probs_test > 0.5).astype(int)  # Convierte a 0 o 1

# Calcular la matriz de confusión
cm = confusion_matrix(y_test, y_pred)



# Graficar la matriz de confusión
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Patologia", "Normal"], yticklabels=["Patologia", "Normal"])
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.title("Matriz de Confusión")


# Graficar la curva ROC
plt.subplot(1,2,2)
plt.plot(fpr, tpr, color='blue', label=f'AUC = {roc_auc:.3f}')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')  # Línea de referencia
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend()
plt.show()

print(f"\nUmbral óptimo: {optimal_threshold}\n" )

# Reporte de clasificación
print("Reporte de Clasificación:\n", classification_report(y_test, y_pred, target_names=['Patologia', 'Normal']))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Umbral óptimo: 0.5102109909057617
#
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#    Patologia       0.69      0.97      0.81       195
#       Normal       0.96      0.56      0.71       195
#
#     accuracy                           0.77       390
#    macro avg       0.82      0.77      0.76       390
# weighted avg       0.82      0.77      0.76       390

# %%
import matplotlib.pyplot as plt
import numpy as np

# Separar las probabilidades según la clase
proba_normal = y_pred_probs_test[y_test == 1]  # Probabilidades de la clase "Normal"
proba_patologia = y_pred_probs_test[y_test == 0]  # Probabilidades de la clase "Patologia"

# Crear histogramas
plt.figure(figsize=(10, 5))
plt.hist(proba_patologia, bins=20, alpha=0.6, label="Patología", color='red', edgecolor='black')
plt.hist(proba_normal, bins=20, alpha=0.6, label="Normal", color='blue', edgecolor='black')

# Personalización
plt.axvline(x=optimal_threshold, color='green', linestyle='dashed', label=f"Umbral óptimo: {optimal_threshold}")
plt.xlabel("Probabilidad de ser Normal")
plt.ylabel("Frecuencia")
plt.title("Distribución de Probabilidades de Clase")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.hist(np.mean(X_train[:,:,0], axis=1), bins=30, alpha=0.5, label="Entrenamiento PPG", color='blue', density=True)
plt.hist(np.mean(X_test[:,:,0], axis=1), bins=30, alpha=0.5, label="Fuera de muestra PPG", color='red', density=True)
plt.xlabel("Media de Amplitud")
plt.ylabel("Densidad")
plt.legend()
plt.title("Comparación de Distribución - PPG")
plt.show()

plt.figure(figsize=(12, 5))
plt.hist(np.mean(cD_array_train, axis=1), bins=30, alpha=0.5, label="Entrenamiento Wavelet", color='blue', density=True)
plt.hist(np.mean(cD_array_test, axis=1), bins=30, alpha=0.5, label="Fuera de muestra Wavelet", color='red', density=True)
plt.xlabel("Media de Amplitud")
plt.ylabel("Densidad")
plt.legend()
plt.title("Comparación de Distribución - Wavelet")
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train[:,:,0])
X_test_pca = pca.transform(X_test[:,:,0])

plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], label="Entrenamiento", alpha=0.5)
plt.scatter(X_test_pca[:, 0], X_test_pca[:, 1], label="Fuera de Muestra", alpha=0.5)
plt.legend()
plt.title("Comparación de Distribución con PCA")
plt.show()

# %% [markdown]
# # Guardar el modelo

# %%
from tensorflow.keras.utils import plot_model
import visualkeras
from PIL import ImageFont

font = ImageFont.truetype("arial.ttf", 32)

plot_model(model, to_file='./Modelos/modelo_cnn_resnet_bilstm/model_plot.png', show_shapes=True, show_layer_names=True)

visualkeras.layered_view(
    model, 
    font=font,
    legend=True, 
    spacing=50,  # Más espacio entre capas
    scale_xy=2,  # Escala horizontal/vertical
    scale_z=1    # Reducir la profundidad 3D para que sea más claro
).save('./Modelos/modelo_cnn_resnet_bilstm/keras_3D.png')

visualkeras.layered_view(
    model, 
    font=font,
    legend=True, 
    spacing=40, 
    draw_volume=False  # Desactiva la vista en 3D
).save('./Modelos/modelo_cnn_resnet_bilstm/keras_2D.png')
# Out:
# C:\Users\Fernando\tfm_env\Lib\site-packages\visualkeras\layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
